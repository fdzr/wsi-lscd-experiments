# %%
import random
import pandas as pd
from sklearn.model_selection import KFold

from helpers_ import (
    train,
    eval,
    calculate_results_for_spectral_clustering_method,
    calculate_average,
    save_parameters_per_method,
    print_results,
)

# %%
k_fold = 5
METHODS = [
    "chinese_whispers",
    "correlation_clustering",
    "wsbm",
    "spectral_clustering",
]
NUMBER_OF_WORDS = 24
TARGET_WORDS = [
    "überspannen",
    "Manschette",
    "Fuß",
    "Rezeption",
    "abgebrüht",
    "Dynamik",
    "Engpaß",
    "abbauen",
    "Mißklang",
    "Abgesang",
    "Knotenpunkt",
    "Spielball",
    "zersetzen",
    "Armenhaus",
    "Ohrwurm",
    "Eintagsfliege",
    "Seminar",
    "Sensation",
    "Titel",
    "Schmiere",
    "ausspannen",
    "packen",
    "artikulieren",
    "abdecken",
]
assert len(TARGET_WORDS) == NUMBER_OF_WORDS

# %%
def get_fields_to_report_results():
    results_per_method = {}
    parameters_per_method = {}
    for method in METHODS:
        parameters_per_method[method] = {"ari": [], "spr_lscd": []}
        if method != "spectral_clustering":
            results_per_method[method] = {"ari": 0.0, "spr_lscd": 0.0}
        else:
            results_per_method[method] = {
                "avg_ari_silhouette": 0.0,
                "avg_ari_calinski": 0.0,
                "avg_ari_eigengap": 0.0,
                "avg_ari_silhouette_old": 0.0,
                "avg_ari_calinski_old": 0.0,
                "avg_ari_eigengap_old": 0.0,
                "avg_ari_silhouette_new": 0.0,
                "avg_ari_calinski_new": 0.0,
                "avg_ari_eigengap_new": 0.0,
                "spr_lscd_silhouette": 0.0,
                "spr_lscd_calinski": 0.0,
                "spr_lscd_eigengap": 0.0,
            }

    return results_per_method, parameters_per_method

results_per_method, parameters_per_method = get_fields_to_report_results()

# %%
kf = KFold(n_splits=k_fold, random_state=32, shuffle=True)
for method in METHODS:
    iteration = 1
    print(f"Method: {method}")

    for train_, test_ in kf.split(TARGET_WORDS):
        best_combination_for_ari, best_combination_for_spr_lscd = train(
            method, train_, TARGET_WORDS
        )
        parameters_per_method[method]["ari"].append(best_combination_for_ari)
        parameters_per_method[method]["spr_lscd"].append(
            best_combination_for_spr_lscd
        )
        ari, spr_lscd = eval(
            method,
            test_,
            best_combination_for_ari,
            best_combination_for_spr_lscd,
            TARGET_WORDS,
        )

        print_results(
            iteration,
            best_combination_for_ari["ari"]
            if "ari" in best_combination_for_ari
            else best_combination_for_ari,
            ari,
            best_combination_for_spr_lscd["spr_lscd"]
            if "spr_lscd" in best_combination_for_spr_lscd
            else best_combination_for_spr_lscd,
            spr_lscd,
        )

        if method != "spectral_clustering":
            results_per_method[method]["ari"] += ari
            results_per_method[method]["spr_lscd"] += spr_lscd
        else:
            ari_and_spr_lscd_calculated_fields = {**ari, **spr_lscd}
            calculate_results_for_spectral_clustering_method(
                results_per_method["spectral_clustering"],
                ari_and_spr_lscd_calculated_fields,
            )

        iteration += 1

calculate_average(results_per_method, METHODS, k_fold)
# Out:
# Method: chinese_whispers
# /home/fzamora/miniconda3/envs/ex/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4916: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
#   Fold-1:
#     dev-ARI: 0.6994453736616235 test-ARI: 0.5516903886516474
#     dev-Spr_LSCD: 0.8541313718020878 test-Spr_LSCD: 0.3947368421052632
#
#   Fold-2:
#     dev-ARI: 0.6792590170598993 test-ARI: 0.6076291157738213
#     dev-Spr_LSCD: 0.8729306113538294 test-Spr_LSCD: 0.8999999999999998
#
#   Fold-3:
#     dev-ARI: 0.7204040209746494 test-ARI: 0.5200483273426302
#     dev-Spr_LSCD: 0.9200355045989487 test-Spr_LSCD: 0.3
#
#   Fold-4:
#     dev-ARI: 0.7386727431467213 test-ARI: 0.5256599023950035
#     dev-Spr_LSCD: 0.9683659274766395 test-Spr_LSCD: 0.35909242322980395
#
#   Fold-5:
#     dev-ARI: 0.6894950731814958 test-ARI: 0.6811327266270648
#     dev-Spr_LSCD: 0.8447056087291156 test-Spr_LSCD: 1.0
#
# Method: correlation_clustering
#   Fold-1:
#     dev-ARI: 0.7182303089218093 test-ARI: 0.8034800735512881
#     dev-Spr_LSCD: 0.8042145329547151 test-Spr_LSCD: 0.9746794344808963
#
#   Fold-2:
#     dev-ARI: 0.7354043346922096 test-ARI: 0.7382187756237669
#     dev-Spr_LSCD: 0.8127803778557416 test-Spr_LSCD: 0.9999999999999999
#
#   Fold-3:
#     dev-ARI: 0.7591539282437187 test-ARI: 0.6479703201280325
#     dev-Spr_LSCD: 0.8845478489903424 test-Spr_LSCD: 0.3
#
#   Fold-4:
#     dev-ARI: 0.7405619651341564 test-ARI: 0.7186197799443689
#     dev-Spr_LSCD: 0.897494472341968 test-Spr_LSCD: 0.3
#
#   Fold-5:
#     dev-ARI: 0.727072237311864 test-ARI: 0.7805828727583836
#     dev-Spr_LSCD: 0.7945051371891977 test-Spr_LSCD: 1.0
#
# Method: wsbm
#   Fold-1:
#     dev-ARI: 0.6482131064386513 test-ARI: 0.6888729695641904
#     dev-Spr_LSCD: 0.9051803313060166 test-Spr_LSCD: 0.8720815992723809
#
#   Fold-2:
#     dev-ARI: 0.6440690158123714 test-ARI: 0.45979981192021
#     dev-Spr_LSCD: 0.8981116368967095 test-Spr_LSCD: 0.9999999999999999
#
#   Fold-3:
#     dev-ARI: 0.6728803659074214 test-ARI: 0.5277348869520774
#     dev-Spr_LSCD: 0.9402985074626865 test-Spr_LSCD: 0.7
#
#   Fold-4:
#     dev-ARI: 0.7221490793540434 test-ARI: 0.37855275180693077
#     dev-Spr_LSCD: 0.9432975234567228 test-Spr_LSCD: 0.49999999999999994
#
#   Fold-5:
#     dev-ARI: 0.6420936158573984 test-ARI: 0.6035299373729881
#     dev-Spr_LSCD: 0.913059906594502 test-Spr_LSCD: 0.39999999999999997
#
# Method: spectral_clustering
#   Fold-1:
#     dev-ARI_Silhouette: 0.7976051453996832 test-ARI_Silhouette: 0.8151272453945575
#     dev-Spr_LSCD_Silhouette: 0.9512945189595297 test-Spr_LSCD_Silhouette: 0.8720815992723809
#
#     dev-ARI-Calinski: 0.7798081442229327 test-ARI_Calinski: 0.8151272453945575
#     dev-Spr_LSCD_Calinski: 0.932281169545808 test-Spr_LSCD_Calinski: 0.9746794344808963
#
#     dev-ARI-Eigengap: 0.6641603724156447 test-ARI_Eigengap: 0.3173611111111111
#     dev-Spr_LSCD_Eigengap: 0.8368723842871333 test-Spr_LSCD_Eigengap: 0.516185401208764
#   Fold-2:
#     dev-ARI_Silhouette: 0.7875598077057525 test-ARI_Silhouette: 0.8532995286314936
#     dev-Spr_LSCD_Silhouette: 0.9499342154560306 test-Spr_LSCD_Silhouette: 0.9999999999999999
#
#     dev-ARI-Calinski: 0.7697628065290021 test-ARI_Calinski: 0.8532995286314936
#     dev-Spr_LSCD_Calinski: 0.9280070237050043 test-Spr_LSCD_Calinski: 0.8999999999999998
#
#     dev-ARI-Eigengap: 0.6109332416460027 test-ARI_Eigengap: 0.6070329088989209
#     dev-Spr_LSCD_Eigengap: 0.8289322198450866 test-Spr_LSCD_Eigengap: 0.9999999999999999
#   Fold-3:
#     dev-ARI_Silhouette: 0.8180472926835503 test-ARI_Silhouette: 0.7374470857158628
#     dev-Spr_LSCD_Silhouette: 0.9341527655838454 test-Spr_LSCD_Silhouette: 0.7
#
#     dev-ARI-Calinski: 0.8002502915067997 test-ARI_Calinski: 0.7374470857158628
#     dev-Spr_LSCD_Calinski: 0.895037416134716 test-Spr_LSCD_Calinski: 0.7
#
#     dev-ARI-Eigengap: 0.6142889562364693 test-ARI_Eigengap: 0.5997512156617759
#     dev-Spr_LSCD_Eigengap: 0.8788081472666657 test-Spr_LSCD_Eigengap: 0.6668859288553501
#   Fold-4:
#     dev-ARI_Silhouette: 0.8092366021305091 test-ARI_Silhouette: 0.7709277098174192
#     dev-Spr_LSCD_Silhouette: 0.9446883230904302 test-Spr_LSCD_Silhouette: 0.6
#
#     dev-ARI-Calinski: 0.7960479885732696 test-ARI_Calinski: 0.7534158368632772
#     dev-Spr_LSCD_Calinski: 0.9433963172338509 test-Spr_LSCD_Calinski: 0.49999999999999994
#
#     dev-ARI-Eigengap: 0.686584323494592 test-ARI_Eigengap: 0.26868679330916134
#     dev-Spr_LSCD_Eigengap: 0.9411764705882352 test-Spr_LSCD_Eigengap: 0.46169025843831935
#   Fold-5:
#     dev-ARI_Silhouette: 0.7942003923898334 test-ARI_Silhouette: 0.8365315354425253
#     dev-Spr_LSCD_Silhouette: 0.9473090622004786 test-Spr_LSCD_Silhouette: 0.7999999999999999
#
#     dev-ARI-Calinski: 0.7898224241512979 test-ARI_Calinski: 0.7738856210456382
#     dev-Spr_LSCD_Calinski: 0.9021820917983444 test-Spr_LSCD_Calinski: 0.7999999999999999
#
#     dev-ARI-Eigengap: 0.6351359548814134 test-ARI_Eigengap: 0.5472017891696396
#     dev-Spr_LSCD_Eigengap: 0.8199367821351428 test-Spr_LSCD_Eigengap: 1.0

# %%
save_parameters_per_method(parameters_per_method, METHODS)

# %%
results_per_method, parameters_per_method = get_fields_to_report_results()

# %%
for method in METHODS:
    iteration = 1
    print(f"Method: {method}")

    for train_, test_ in kf.split(TARGET_WORDS):
        best_combination_for_ari, best_combination_for_spr_lscd = train(
            method, train_, TARGET_WORDS
        )
        parameters_per_method[method]["ari"].append(best_combination_for_ari)
        parameters_per_method[method]["spr_lscd"].append(
            best_combination_for_spr_lscd
        )
        ari, spr_lscd = eval(
            method,
            test_,
            best_combination_for_ari,
            best_combination_for_spr_lscd,
            TARGET_WORDS,
            exchange_optimized_parameters=True
        )

        print_results(
            iteration,
            best_combination_for_ari["ari"]
            if "ari" in best_combination_for_ari
            else best_combination_for_ari,
            ari,
            best_combination_for_spr_lscd["spr_lscd"]
            if "spr_lscd" in best_combination_for_spr_lscd
            else best_combination_for_spr_lscd,
            spr_lscd,
        )

        if method != "spectral_clustering":
            results_per_method[method]["ari"] += ari
            results_per_method[method]["spr_lscd"] += spr_lscd
        else:
            ari_and_spr_lscd_calculated_fields = {**ari, **spr_lscd}
            calculate_results_for_spectral_clustering_method(
                results_per_method["spectral_clustering"],
                ari_and_spr_lscd_calculated_fields,
            )

        iteration += 1

calculate_average(results_per_method, METHODS, k_fold)
# Out:
# Method: chinese_whispers
#   Fold-1:
#     dev-ARI: 0.6994453736616235 test-ARI: 0.4472319613793063
#     dev-Spr_LSCD: 0.8541313718020878 test-Spr_LSCD: 0.9746794344808963
#
#   Fold-2:
#     dev-ARI: 0.6792590170598993 test-ARI: 0.7222222259639388
#     dev-Spr_LSCD: 0.8729306113538294 test-Spr_LSCD: 0.7999999999999999
#
#   Fold-3:
#     dev-ARI: 0.7204040209746494 test-ARI: 0.49203251628172284
#     dev-Spr_LSCD: 0.9200355045989487 test-Spr_LSCD: 0.3
#
#   Fold-4:
#     dev-ARI: 0.7386727431467213 test-ARI: 0.6175118515494609
#     dev-Spr_LSCD: 0.9683659274766395 test-Spr_LSCD: 0.5642880936468347
#
#   Fold-5:
#     dev-ARI: 0.6894950731814958 test-ARI: 0.6189588558827837
#     dev-Spr_LSCD: 0.8447056087291156 test-Spr_LSCD: 0.7999999999999999
#
# Method: correlation_clustering
#   Fold-1:
#     dev-ARI: 0.7182303089218093 test-ARI: 0.5995437211318104
#     dev-Spr_LSCD: 0.8042145329547151 test-Spr_LSCD: 0.9746794344808963
#
#   Fold-2:
#     dev-ARI: 0.7354043346922096 test-ARI: 0.7725347913931706
#     dev-Spr_LSCD: 0.8127803778557416 test-Spr_LSCD: 0.9999999999999999
#
#   Fold-3:
#     dev-ARI: 0.7591539282437187 test-ARI: 0.4957846225579958
#     dev-Spr_LSCD: 0.8845478489903424 test-Spr_LSCD: 0.39999999999999997
#
#   Fold-4:
#     dev-ARI: 0.7405619651341564 test-ARI: 0.4478951213431685
#     dev-Spr_LSCD: 0.897494472341968 test-Spr_LSCD: 0.6
#
#   Fold-5:
#     dev-ARI: 0.727072237311864 test-ARI: 0.6555339123883548
#     dev-Spr_LSCD: 0.7945051371891977 test-Spr_LSCD: 0.7999999999999999
#
# Method: wsbm
#   Fold-1:
#     dev-ARI: 0.6482131064386513 test-ARI: 0.6888729695641904
#     dev-Spr_LSCD: 0.9051803313060166 test-Spr_LSCD: 0.8720815992723809
#
#   Fold-2:
#     dev-ARI: 0.6440690158123714 test-ARI: 0.7304572401396722
#     dev-Spr_LSCD: 0.8981116368967095 test-Spr_LSCD: 0.8999999999999998
#
#   Fold-3:
#     dev-ARI: 0.6728803659074214 test-ARI: 0.29355019995392617
#     dev-Spr_LSCD: 0.9402985074626865 test-Spr_LSCD: 0.7
#
#   Fold-4:
#     dev-ARI: 0.7221490793540434 test-ARI: 0.5199216229706034
#     dev-Spr_LSCD: 0.9432975234567228 test-Spr_LSCD: 0.8999999999999998
#
#   Fold-5:
#     dev-ARI: 0.6420936158573984 test-ARI: 0.4551092715258123
#     dev-Spr_LSCD: 0.913059906594502 test-Spr_LSCD: 0.39999999999999997
#
# Method: spectral_clustering
#   Fold-1:
#     dev-ARI_Silhouette: 0.7976051453996832 test-ARI_Silhouette: 0.8151272453945575
#     dev-Spr_LSCD_Silhouette: 0.9512945189595297 test-Spr_LSCD_Silhouette: 0.8720815992723809
#
#     dev-ARI-Calinski: 0.7798081442229327 test-ARI_Calinski: 0.7353497441814578
#     dev-Spr_LSCD_Calinski: 0.932281169545808 test-Spr_LSCD_Calinski: 0.8720815992723809
#
#     dev-ARI-Eigengap: 0.6641603724156447 test-ARI_Eigengap: 0.3173611111111111
#     dev-Spr_LSCD_Eigengap: 0.8368723842871333 test-Spr_LSCD_Eigengap: 0.516185401208764
#   Fold-2:
#     dev-ARI_Silhouette: 0.7875598077057525 test-ARI_Silhouette: 0.8532995286314936
#     dev-Spr_LSCD_Silhouette: 0.9499342154560306 test-Spr_LSCD_Silhouette: 0.9999999999999999
#
#     dev-ARI-Calinski: 0.7697628065290021 test-ARI_Calinski: 0.6488897502650972
#     dev-Spr_LSCD_Calinski: 0.9280070237050043 test-Spr_LSCD_Calinski: 0.9999999999999999
#
#     dev-ARI-Eigengap: 0.6109332416460027 test-ARI_Eigengap: 0.7801067403775599
#     dev-Spr_LSCD_Eigengap: 0.8289322198450866 test-Spr_LSCD_Eigengap: 0.7
#   Fold-3:
#     dev-ARI_Silhouette: 0.8180472926835503 test-ARI_Silhouette: 0.5997512156617759
#     dev-Spr_LSCD_Silhouette: 0.9341527655838454 test-Spr_LSCD_Silhouette: 0.8999999999999998
#
#     dev-ARI-Calinski: 0.8002502915067997 test-ARI_Calinski: 0.6857880036056188
#     dev-Spr_LSCD_Calinski: 0.895037416134716 test-Spr_LSCD_Calinski: 0.8999999999999998
#
#     dev-ARI-Eigengap: 0.6142889562364693 test-ARI_Eigengap: 0.6549562629803878
#     dev-Spr_LSCD_Eigengap: 0.8788081472666657 test-Spr_LSCD_Eigengap: 0.7
#   Fold-4:
#     dev-ARI_Silhouette: 0.8092366021305091 test-ARI_Silhouette: 0.6800895829352296
#     dev-Spr_LSCD_Silhouette: 0.9446883230904302 test-Spr_LSCD_Silhouette: 0.8999999999999998
#
#     dev-ARI-Calinski: 0.7960479885732696 test-ARI_Calinski: 0.7113020231804293
#     dev-Spr_LSCD_Calinski: 0.9433963172338509 test-Spr_LSCD_Calinski: 0.7
#
#     dev-ARI-Eigengap: 0.686584323494592 test-ARI_Eigengap: 0.26868679330916134
#     dev-Spr_LSCD_Eigengap: 0.9411764705882352 test-Spr_LSCD_Eigengap: 0.46169025843831935
#   Fold-5:
#     dev-ARI_Silhouette: 0.7942003923898334 test-ARI_Silhouette: 0.8365315354425253
#     dev-Spr_LSCD_Silhouette: 0.9473090622004786 test-Spr_LSCD_Silhouette: 0.7999999999999999
#
#     dev-ARI-Calinski: 0.7898224241512979 test-ARI_Calinski: 0.7566936530201843
#     dev-Spr_LSCD_Calinski: 0.9021820917983444 test-Spr_LSCD_Calinski: 0.7999999999999999
#
#     dev-ARI-Eigengap: 0.6351359548814134 test-ARI_Eigengap: 0.609107008646427
#     dev-Spr_LSCD_Eigengap: 0.8199367821351428 test-Spr_LSCD_Eigengap: 1.0
